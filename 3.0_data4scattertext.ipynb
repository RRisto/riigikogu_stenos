# %%
import pandas as pd

# %%
df=pd.read_csv('data/interim/stenos_cleaned_faction2022.csv')
df.shape
# Out:
# (241366, 17)

# %%
df.head()
# Out:
#                                              heading                 speaker  \
# 0                         10:00  Istungi rakendamine  Aseesimees Siim Kallas
# 1  1.\n                        10:02  Eesti Keske...  Aseesimees Siim Kallas
# 2  1.\n                        10:02  Eesti Keske...          Kersti Sarapuu
# 3  1.\n                        10:02  Eesti Keske...  Aseesimees Siim Kallas
# 4  1.\n                        10:02  Eesti Keske...             Aivar Sõerd
#
#                                           link_video  \
# 0    https://www.youtube.com/watch?v=GaFL2Zc4OMg&t=0
# 1  https://www.youtube.com/watch?v=GaFL2Zc4OMg&t=125
# 2  https://www.youtube.com/watch?v=GaFL2Zc4OMg&t=238
# 3  https://www.youtube.com/watch?v=GaFL2Zc4OMg&t=...
# 4  https://www.youtube.com/watch?v=GaFL2Zc4OMg&t=...
#
#                                        link_steno   index_pk   index_snd  \
# 0  https://stenogrammid.riigikogu.ee/201911191000  PKP-25040  SND-559399
# ...

# %%
df.tail()
# Out:
#                                             heading             speaker  \
# 241361  2.\n                        10:15 Jõuluvana           Jõuluvana
# 241362  2.\n                        10:15 Jõuluvana          Jaak Juske
# 241363  2.\n                        10:15 Jõuluvana           Jõuluvana
# 241364  2.\n                        10:15 Jõuluvana  Toomas Jürgenstein
# 241365  2.\n                        10:15 Jõuluvana           Jõuluvana
#
#                                                link_video  \
# 241361  https://www.youtube.com/watch?v=Wxpvs5IFpn4&t=...
# 241362  https://www.youtube.com/watch?v=Wxpvs5IFpn4&t=...
# 241363  https://www.youtube.com/watch?v=Wxpvs5IFpn4&t=...
# 241364  https://www.youtube.com/watch?v=Wxpvs5IFpn4&t=...
# 241365  https://www.youtube.com/watch?v=Wxpvs5IFpn4&t=...
#
#                                             link_steno    index_pk  \
# 241361  https://stenogrammid.riigikogu.ee/202212151000  PKP-565151
# ...

# %%
df.speaker.value_counts()[:40]
# Out:
# Esimees Eiki Nestor               15084
# Aseesimees Jüri Ratas             14039
# Aseesimees Helir-Valdor Seeder    10837
# Esimees Ene Ergma                  9211
# Aseesimees Laine Randjärv          8664
# Esimees Jüri Ratas                 7987
# Aseesimees Hanno Pevkur            7204
# Aseesimees Enn Eesmaa              6338
# Aseesimees Martin Helme            6010
# Esimees Henn Põlluaas              5201
# Aseesimees Keit Pentus             3049
# Aseesimees Siim Kallas             3003
# Peeter Ernits                      2800
# Peaminister Jüri Ratas             2099
# Peaminister Kaja Kallas            2080
# Aivar Kokk                         2037
# Mihhail Stalnuhhin                 1905
# Esimees Lauri Hussar               1878
# Henn Põlluaas                      1669
# Mart Helme                         1644
# Andres Herkel                      1615
# Jürgen Ligi                        1612
# Kadri Simson                       1535
# ...

# %%
df_subset=df[df.speaker.isin(['Jevgeni Ossinovski', 'Aivar Sõerd'])]
df_subset.shape
# Out:
# (2581, 17)

# %%
df_subset.to_excel('data/scattertext/ossin_soerd.xlsx', index=False)
